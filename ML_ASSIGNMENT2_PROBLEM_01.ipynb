# %% [markdown]
# <a href="https://colab.research.google.com/github/CopotronicRifat/CS-5783-Machine-Learning-Assignments/blob/main/ML_ASSIGNMENT2_PROBLEM_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem 1**
#
# **Derivation of update rule:**
#
# The cost function we try to minimize for a regression analysis is generally mean squared error which is-
#
# The Forward Pass:
#
# $$net_h1 = input * weights + b1$$
# $$Out_h1 = sigmoid(net_h1)$$
#
# $$net_h2 = input * weights + b2$$
# $$Out_h2 = sigmoid(net_h2)$$
#
# The Backward Pass:
#
# $$ Output = Out * weight$$
# ![Screenshot 2022-10-07 235126.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2022-10-07 235215.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2022-10-07 235335.png](data:image/png;base64,...)
